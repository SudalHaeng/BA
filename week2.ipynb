# %% [markdown]
# # 베이스볼 아카데미 2주차
# ### Python 기초 문법
# > 파이썬 원리에 대해 이해한다.

# %%
# 주석 : 여기 안에서 메모장


'''
메모장
'''

"""
메모장
"""
# Out:
# '\n메모장\n'

# %%
a = 150
print(a)
a
# Out:
# 150
# 150

# %%
b="류현진"
print(b)
# Out:
# 류현진

# %%
b
# Out:
# '류현진'

# %%
a= 150
b= 170
(a+b)/2
# Out:
# 160.0

# %% [markdown]
# > 비교 연산자
#  1. '==' 값이 동일하다
#  2. '!=' 값이 동일하지 않다
#  3. '>'  왼쪽 값이 더 크다
#  4. '<'  왼쪽 값이 더 작다
#  5. '>=' 왼쪽 값이 크거나 동일하다
#  6. '<=' 왼쪽 값이 작거나 동일하다

# %%
a==b
# Out:
# False

# %%
a= 105 ; b= 104
a!=b
# Out:
# True

# %%
print(a,b)
a=b
print(a,b)
# Out:
# 105 104
# 104 104

# %%
ryu1=149; ryu2=148; ryu3=151
ryu4=(ryu1+ryu2+ryu3)/3
print(ryu4)
# Out:
# 149.33333333333334

# %%
ryu1>ryu2
# Out:
# True

# %%
ryu5=ryu1-ryu2
print(ryu5)
ryu5>0
# Out:
# 1
# True

# %%
a='Hyun jin Ryu'
b='Hyun jin Ryu'
print(a==b)
# Out:
# True

# %%
c=a+"99"
print(c)
# Out:
# Hyun jin Ryu99

# %%
a,b,c=150,151,158
print(a,b,c)
# Out:
# 150 151 158

# %%
if a<b :
  print(a)
# Out:
# 150

# %%
if b>c :
  print(a,b)
elif a<c:
  print(c)
# Out:
# 158

# %%
if b<c:
  print(a,b)
elif a<c:
  print(c)
# Out:
# 150 151

# %%
if b>c:
  print(b)
elif a>c:
  print(c)
else:
  print(a)
# Out:
# 150

# %%
Ryu=False
Toronto=False
print(Ryu)
print(Toronto)
# Out:
# False
# False

# %%
Ryu==False
# Out:
# True

# %%
Ryu=="False"
# Out:
# False

# %%
if Ryu==True:
  print("류는 True")
else:
  print("류는 False")
# Out:
# 류는 False

# %%
if Ryu==True:
  print("류현진")
else:
  print("류현진 아님")
  if Toronto==True:
    print("토론토 소속")
  else:
    print("토론토 소속 아님")
# Out:
# 류현진 아님
# 토론토 소속 아님

# %%
def asdf():
  if Ryu==True:
    print("류현진")
  else:
    print("류현진 아님")
    if Toronto==True:
      print("토론토 소속")
    else:
      print("토론토 소속 아님")

# %%
asdf()
# Out:
# 류현진 아님
# 토론토 소속 아님

# %%
def asdf(Ryu, Toronto):
  if Ryu==True:
    print("류현진")
  else:
    print("류현진 아님")
    if Toronto==True:
      print("토론토 소속")
    else:
      print("토론토 소속 아님")

# %%
asdf(Ryu, Toronto)
# Out:
# 류현진 아님
# 토론토 소속 아님

# %%
asdf(Ryu=True, Toronto=False)
# Out:
# 류현진

# %%
asdf(Ryu=False, Toronto=True)
# Out:
# 류현진 아님
# 토론토 소속

# %%
#리스트 : 값을 여러개 묶어 저장 
Speed=[0 , 50 , 100 , 102 , 5000]
#      0   1     2     3     4
Speed
# Out:
# [0, 50, 100, 102, 5000]

# %%
Speed[0], Speed[1]
# Out:
# (0, 50)

# %%
#문자열 리스트
Players=['마차도','로하스','Ryu','Posey','Bauer']
Players
# Out:
# ['마차도', '로하스', 'Ryu', 'Posey', 'Bauer']

# %%
Players[3]
# Out:
# 'Posey'

# %%
for a in Players:
  print(a)
# Out:
# 마차도
# 로하스
# Ryu
# Posey
# Bauer

# %%
for a in Speed:
  print(a)
# Out:
# 0
# 50
# 100
# 102
# 5000

# %%
Players.append("김성근")

# %%
Players[0:2]
# Out:
# ['마차도', '로하스']

# %%
Players[3:5]
# Out:
# ['Posey', 'Bauer']

# %%
Players[0:2].append("추신수")+Players[3:6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-38466fcd288f> in <module>()
# ----> 1 Players[0:2].append("추신수")+Players[3:6]
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'list'

# %%
Players[3:6]
# Out:
# ['Posey', 'Bauer', '김성근']

# %%
#for 반복(Loop)
#ragne(x) = range(0, x) , 0에서 x-1까지
#for i in range(x) 
#i를 0에서 x-1까지 바꿔가면서 루프를 돌려라

# %%
for i in range(5):
  print(Speed[i])
# Out:
# 0
# 50
# 100
# 102
# 5000

# %%
for i in range(5):
  print(i,Speed[i])
# Out:
# 0 0
# 1 50
# 2 100
# 3 102
# 4 5000

# %%
for i in range(len(Speed)):
  print(i,Speed[i])
# Out:
# 0 0
# 1 50
# 2 100
# 3 102
# 4 5000

# %%
len(Speed)
# Out:
# 5

# %%
a=0
for i in range(101):
  a+=i
print(a)
# Out:
# 5050

# %%
a=0
for i in range(1,101,2):
  a+=i
print(a)
# Out:
# 2500

# %%
a=1
for i in range(1,11):
  a=a*3
print(a)
# Out:
# 59049

# %%
# Out:
# ...

# %% [markdown]
# # 3주차 수업
